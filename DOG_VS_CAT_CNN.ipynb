# %% [markdown]
# ##Steps for solving Image Classification Problem are described below:
# 1. Import necessary Libraries.
# 2. Prepare Training Data and Visualize it
# 3. Split dataset into training and validation set
# 4. Build a predictive model
# 5. Fit the predictive model into the training dataset
# 6. Prepare training dataset and visualize it
# 7. Predict the testing dataset.
#
# The programming for these steps are given below:

# %%
pip install git+https://github.com/sat28/githubcommit.git
# Out:
# ...
#   Cloning https://github.com/sat28/githubcommit.git to c:\users\dell\appdata\local\temp\pip-req-build-eo9i63v1
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/sat28/githubcommit.git 'C:\Users\Dell\AppData\Local\Temp\pip-req-build-eo9i63v1'
#   ERROR: Error [WinError 2] The system cannot find the file specified while executing command git clone -q https://github.com/sat28/githubcommit.git 'C:\Users\Dell\AppData\Local\Temp\pip-req-build-eo9i63v1'
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?

# %%
import numpy as np
import pandas as pd
import os
import random
import matplotlib.pyplot as plt
import seaborn as sns
from keras.preprocessing import image
from sklearn.model_selection import train_test_split
from numpy import unique, argmax
from keras import backend as K

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
Directories = r"E:\crypto_data\dogscats\train"
Categories = ['cats', 'dogs']
IMG_SIZE = 64
data = []

# %%
for category in Categories:
    folder = os.path.join(Directories, category)
    label = Categories.index(category)
    for image in os.listdir(folder):
        image_path = os.path.join(folder, image)
        img_arr = cv2.imread(image_path)
        img_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
        data.append([img_arr, label])

# %%
len(data)
# Out:
# 23000

# %%
random.shuffle(data)

# %%
from pylab import *

# %%
X_train = []
y_train = []

for features, labels in data:
    X_train.append(features)
    y_train.append(labels)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
len(X_train)
# Out:
# 23000

# %%
len(y_train)
# Out:
# 23000

# %%
X_train[0]
# Out:
# array([[[127, 123, 129],
#         [128, 124, 130],
#         [130, 126, 132],
#         ...,
#         [186, 179, 182],
#         [186, 179, 182],
#         [184, 176, 182]],
#
#        [[129, 125, 131],
#         [130, 126, 132],
#         [132, 129, 135],
#         ...,
#         [186, 179, 183],
#         [187, 180, 183],
#         [185, 177, 183]],
#
#        [[130, 126, 132],
#         [133, 129, 135],
#         [135, 131, 137],
#         ...,
#         [188, 181, 184],
#         [188, 181, 184],
#         [186, 178, 184]],
#
#        ...,
#
#        [[ 28,  19,  22],
#         [ 24,  24,  25],
#         [ 32,  28,  29],
#         ...,
#         [111, 178, 202],
#         [120, 185, 204],
#         [102, 169, 182]],
#
#        [[ 83,  63,  68],
#         [ 90,  77,  81],
#         [141, 130, 132],
#         ...,
#         [110, 181, 205],
#         [113, 184, 203],
#         [129, 175, 195]],
#
#        [[ 18,  21,  26],
#         [ 84,  83,  89],
#         [146, 135, 140],
# ...

# %%
imshow(X_train[0])

# %%
X_train.shape[1:]
# Out:
# (64, 64, 3)

# %%
y_train[0]
# Out:
# 0

# %%
Directories = r"E:\crypto_data\dogscats\valid"
Categories = ['cats', 'dogs']
IMG_SIZE = 64
data = []

# %%
for category in Categories:
    folder = os.path.join(Directories, category)
    label = Categories.index(category)
    for image in os.listdir(folder):
        image_path = os.path.join(folder, image)
        img_arr = cv2.imread(image_path)
        img_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
        data.append([img_arr, label])

# %%
len(data)
# Out:
# 2000

# %%
from random import shuffle

# %%
X_test = []
y_test = []
for features, labels in data:
    X_test.append(features)
    y_test.append(labels)

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
len(X_test)
# Out:
# 2000

# %%
len(y_test)
# Out:
# 2000

# %%
X_train[0]
# Out:
# array([[[127, 123, 129],
#         [128, 124, 130],
#         [130, 126, 132],
#         ...,
#         [186, 179, 182],
#         [186, 179, 182],
#         [184, 176, 182]],
#
#        [[129, 125, 131],
#         [130, 126, 132],
#         [132, 129, 135],
#         ...,
#         [186, 179, 183],
#         [187, 180, 183],
#         [185, 177, 183]],
#
#        [[130, 126, 132],
#         [133, 129, 135],
#         [135, 131, 137],
#         ...,
#         [188, 181, 184],
#         [188, 181, 184],
#         [186, 178, 184]],
#
#        ...,
#
#        [[ 28,  19,  22],
#         [ 24,  24,  25],
#         [ 32,  28,  29],
#         ...,
#         [111, 178, 202],
#         [120, 185, 204],
#         [102, 169, 182]],
#
#        [[ 83,  63,  68],
#         [ 90,  77,  81],
#         [141, 130, 132],
#         ...,
#         [110, 181, 205],
#         [113, 184, 203],
#         [129, 175, 195]],
#
#        [[ 18,  21,  26],
#         [ 84,  83,  89],
#         [146, 135, 140],
# ...

# %%
imshow(X_test[0])

# %%
y_test[0]
# Out:
# 0

# %%
pip install np_utils
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Activation
from tensorflow.keras.utils import plot_model

# %%
import pandas as pd

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
X_train[0]
# Out:
# array([[[0.49803922, 0.48235294, 0.5058824 ],
#         [0.5019608 , 0.4862745 , 0.50980395],
#         [0.50980395, 0.49411765, 0.5176471 ],
#         ...,
#         [0.7294118 , 0.7019608 , 0.7137255 ],
#         [0.7294118 , 0.7019608 , 0.7137255 ],
#         [0.72156864, 0.6901961 , 0.7137255 ]],
#
#        [[0.5058824 , 0.49019608, 0.5137255 ],
#         [0.50980395, 0.49411765, 0.5176471 ],
#         [0.5176471 , 0.5058824 , 0.5294118 ],
#         ...,
#         [0.7294118 , 0.7019608 , 0.7176471 ],
#         [0.73333335, 0.7058824 , 0.7176471 ],
#         [0.7254902 , 0.69411767, 0.7176471 ]],
#
#        [[0.50980395, 0.49411765, 0.5176471 ],
#         [0.52156866, 0.5058824 , 0.5294118 ],
#         [0.5294118 , 0.5137255 , 0.5372549 ],
#         ...,
#         [0.7372549 , 0.70980394, 0.72156864],
#         [0.7372549 , 0.70980394, 0.72156864],
#         [0.7294118 , 0.69803923, 0.72156864]],
#
#        ...,
#
#        [[0.10980392, 0.07450981, 0.08627451],
# ...

# %%
y_train.shape
# Out:
# (23000,)

# %%
X_train.shape
# Out:
# (23000, 64, 64, 3)

# %%
model_1 = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=X_train.shape[1:], padding="same"),
    BatchNormalization(),
    Conv2D(48, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation="relu"),
    Dense(1, activation="sigmoid")
    
])

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  batch_normalization (BatchN  (None, 64, 64, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 62, 62, 48)        13872
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 48)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 48)        0
#
#  flatten (Flatten)           (None, 46128)             0
#
#  dense (Dense)               (None, 128)               5904512
#
#  dense_1 (Dense)             (None, 1)                 129
#
# ...
# Total params: 5,919,537
# Trainable params: 5,919,473
# Non-trainable params: 64
# _________________________________________________________________

# %%
pip install pydot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plot-model
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model_1, 'model_1.jpg', show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model_1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_1 = model_1.fit(X_train, y_train, epochs=10, batch_size=128, validation_data=(X_test/255., y_test))
# Out:
# Epoch 1/10
# 180/180 [==============================] - 157s 870ms/step - loss: 342.7191 - accuracy: 0.5063 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/10
# 180/180 [==============================] - 189s 1s/step - loss: 0.6919 - accuracy: 0.5367 - val_loss: 0.6947 - val_accuracy: 0.5000
# Epoch 3/10
# 180/180 [==============================] - 154s 856ms/step - loss: 0.6888 - accuracy: 0.5526 - val_loss: 0.7001 - val_accuracy: 0.5000
# Epoch 4/10
# 180/180 [==============================] - 159s 880ms/step - loss: 0.6840 - accuracy: 0.5679 - val_loss: 0.7062 - val_accuracy: 0.5000
# Epoch 5/10
# 180/180 [==============================] - 160s 888ms/step - loss: 0.6774 - accuracy: 0.5890 - val_loss: 0.7279 - val_accuracy: 0.5000
# Epoch 6/10
# 180/180 [==============================] - 160s 886ms/step - loss: 0.6687 - accuracy: 0.6115 - val_loss: 0.7661 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
pd.DataFrame(history_1.history).plot(figsize=(10,7))
# Out:
# <AxesSubplot:>

# %%
def plot_loss_curves(history):
 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()


  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history_1)

# %%
loss, accuracy = model_1.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 3s 53ms/step - loss: 0.6166 - accuracy: 0.6930

# %%
print(f"Accuracy of the given model is: {accuracy*100}")
# Out:
# Accuracy of the given model is: 69.30000185966492

# %%
Directory = r"E:\crypto_data\dogscats\test1"
IMG_SIZE = 64
data = []
for image in os.listdir(Directory):
    image_path = os.path.join(Directory, image)
    img_arr = cv2.imread(image_path)
    if img_arr is None:
        print('Wrong path', path)
        break
    else:
        img_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
        data.append([img_arr])

# %%
len(data)
# Out:
# 12500

# %%
X_valid = []
for features in data:
    X_valid.append(features)

# %%
X_valid = np.array(X_valid)

# %%
X_valid.shape
# Out:
# (12500, 1, 64, 64, 3)

# %%
X_valid = X_valid.reshape(12500, 64, 64, 3)

# %%
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, 1+i)
    plt.imshow(X_valid[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
image = X_valid[5]

# %%
imshow(image)

# %%
plt.imshow(np.squeeze(image))

# %%
image = image.reshape(1, 64, 64, 3)

# %%
predicted = model_1.predict([image])
p = argmax(predicted)
print('Predicted: {}'.format(argmax(predicted)))
# Out:
# Predicted: 0

# %%
print(f"The object shown in the picture is:", Categories[p])
# Out:
# The object shown in the picture is: cats
